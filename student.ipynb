# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Peter Kinyanjui
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name: Faith Rotich
# * Blog post URL:

# %% [markdown]
# ## Business Problem
# Microsoft sees all the big companies creating original video content and they want to get in on the fun. They have decided to create a new movie studio, but they don’t know anything about creating movies. You are charged with exploring what types of films are currently doing the best at the box office. You must then translate those findings into actionable insights that the head of Microsoft's new movie studio can use to help decide what type of films to create.
#
# ## Use Case:
# We all enjoy watching movies but there are specifics genres that we prefer more than others.There are soo many companies that have venntured in this field of creating original video content.Having been task to give microsoft company an actionable insights it's worthy noting that the global entertainment industry, especially the film sector, presents a lucrative market opportunity. The success of original content in the form of movies has been demonstrated by various industry players.Also, establishing a movie studio is a significant investment for Microsoft. The success of this venture is crucial to diversify revenue streams and expand Microsoft's presence in the entertainment sector.
# ### The analysis seeks to answer the following 3 questions:
# -  Which is the best genre?
# -  Which is the best studio?
# -  Most suitable length of the Video.

# %%
# importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing Data
title_df = pd.read_csv('title.basics.csv')
rating_df = pd.read_csv('title.ratings.csv')
gross_df = pd.read_csv('bom.movie_gross.csv')

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# # Steps:
# - Handling Missing Values
# - Handling Outliers
# - Handling Columns Data types
# - Creating Required Columns

# %%
#title Data overview
title_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
#First 5 rows 
title_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
#rating data overview
rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
#First 5 row
rating_df.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
#gross data overview 
gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
#first 5 rows
gross_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
# Dropping rows with Null values
title_df.dropna()
# Out:
#            tconst                                      primary_title  \
# 0       tt0063540                                          Sunghursh
# 1       tt0066787                    One Day Before the Rainy Season
# 2       tt0069049                         The Other Side of the Wind
# 4       tt0100275                           The Wandering Soap Opera
# 5       tt0111414                                        A Thin Life
# ...           ...                                                ...
# 146134  tt9916160                                         Drømmeland
# 146135  tt9916170                                      The Rehearsal
# 146136  tt9916186  Illenau - die Geschichte einer ehemaligen Heil...
# 146137  tt9916190                                          Safeguard
# 146139  tt9916538                                Kuambil Lagi Hatiku
#
#                                            original_title  start_year  \
# ...

# %%
# Dropping rows with Null values
rating_df.dropna()
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
# Dropping rows with Null values
gross_df.dropna()
# Out:
#                                                   title        studio  \
# 0                                           Toy Story 3            BV
# 1                            Alice in Wonderland (2010)            BV
# 2           Harry Potter and the Deathly Hallows Part 1            WB
# 3                                             Inception            WB
# 4                                   Shrek Forever After          P/DW
# ...                                                 ...           ...
# 3275                                    I Still See You           LGF
# 3286                              The Catcher Was a Spy           IFC
# 3309                                         Time Freak    Grindstone
# 3342  Reign of Judges: Title of Liberty - Concept Short  Darin Southa
# 3353            Antonio Lopez 1970: Sex Fashion & Disco            FM
#
#       domestic_gross foreign_gross  year
# 0        415000000.0     652000000  2010
# 1        334200000.0     691300000  2010
# ...

# %%
#checking for outliers
sns.boxplot(x = title_df['runtime_minutes'])
plt.show()

# %%
# Removing 2 major Outliers
title_df.drop(title_df[title_df['runtime_minutes'] >= 10000].index, inplace = True)
sns.boxplot(x = title_df['runtime_minutes'])
plt.show()

# %%
#Combining the title to the rating Dataset
title_rating_df = pd.merge(title_df, rating_df, on='tconst')
title_rating_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
#changing the data type foreign to Float
gross_df['foreign_gross'] = gross_df['foreign_gross'].str.replace(',', '')
gross_df['foreign_gross'] = gross_df['foreign_gross'].astype(float)
gross_df.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross     float64
# year                int64
# dtype: object

# %%
# Adding a calculted column Total Gross
gross_df['total_gross'] = gross_df['domestic_gross'] + gross_df['foreign_gross']
gross_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year   total_gross
# 0    652000000.0  2010  1.067000e+09
# 1    691300000.0  2010  1.025500e+09
# 2    664300000.0  2010  9.603000e+08
# 3    535700000.0  2010  8.283000e+08
# 4    513900000.0  2010  7.526000e+08

# %% [markdown]
# # Visualizations
# The following Visualizations have been used:
# -  Bar chart
# -  Scatter plot
# -  Line graph
# -  Horizontal Bar chart
# -  Histogram

# %%
# bar chart best rated genre

genre_ratings = title_rating_df.groupby('genres')['averagerating'].mean().reset_index()

# Sort the genres by rating in descending order and select the top 5
top_5_genres = genre_ratings.nlargest(5, 'averagerating')

# Create a bar graph to visualize the top 5 highest-rated genres
plt.figure(figsize=(9, 7))
plt.bar(top_5_genres['genres'], top_5_genres['averagerating'])
plt.xlabel('Movie Genre')
plt.ylabel('Average Rating')
plt.title('Top 5 Highest-Rated Movie Genres')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)  
plt.tight_layout()

# Show the bar graph
plt.show()

# %%
# Scatter plot best rated genre
genre_ratings = title_rating_df.groupby('genres')['averagerating'].mean().reset_index()

# Sort the genres by rating in descending order and select the top 5
top_5_genres = genre_ratings.nlargest(5, 'averagerating')

# Create a scatter plot to visualize the top 5 highest-rated genres
plt.figure(figsize=(9, 7))
plt.scatter(top_5_genres['genres'], top_5_genres['averagerating'])
plt.xlabel('Movie Genre')
plt.ylabel('Average Rating')
plt.title('Top 5 Highest-Rated Movie Genres')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)  
plt.tight_layout()

# Show the scatter plot
plt.show()

# %%
#Bar chart highest studio in total gross
studio_ratings = gross_df.groupby('studio')['total_gross'].sum().reset_index()

# Sort the studios by rating in descending order and select the top 5
top_5_studio = studio_ratings.nlargest(5, 'total_gross')

# Create a bar graph to visualize the top 5 studios with highest total gross
plt.figure(figsize=(9, 7))
plt.bar(top_5_studio['studio'], top_5_studio['total_gross'], color='green')
plt.xlabel('studios')
plt.ylabel('total gross')
plt.title('Top 5 studio with Highest total gross')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)  
plt.tight_layout()

# Show the bar graph
plt.show()

# %%
#Line graph highest studio in total gross
studio_ratings = gross_df.groupby('studio')['total_gross'].sum().reset_index()

# Sort the studios by rating in descending order and select the top 5
top_5_studio = studio_ratings.nlargest(5, 'total_gross')

# Create a bar graph to visualize the top 5 studios with highest total gross
plt.figure(figsize=(9, 7))
plt.plot(top_5_studio['studio'], top_5_studio['total_gross'], color='green')
plt.xlabel('studios')
plt.ylabel('total gross')
plt.title('Top 5 Highest-Rated Movie Genres')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)  
plt.tight_layout()

# Show the bar graph
plt.show()

# %%
#Revoming null values in runtime_minutes column
title_rating_df.dropna()
# Out:
#           tconst                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 6      tt0137204                  Joe Finds Grace             Joe Finds Grace
# ...          ...                              ...                         ...
# 73847  tt9911774        Padmavyuhathile Abhimanyu   Padmavyuhathile Abhimanyu
# 73848  tt9913056                     Swarm Season                Swarm Season
# 73849  tt9913084                 Diabolik sono io            Diabolik sono io
# 73850  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73853  tt9916160                       Drømmeland                  Drømmeland
#
# ...

# %%
#Horizontal bar graph Highest-Rated Movie Genres with Average Runtime
genre_runtime = title_rating_df.groupby('genres')['runtime_minutes'].mean().reset_index()
genre_ratings_runtime = genre_ratings.merge(genre_runtime, on='genres', how='inner')

# Sort the genres by rating in descending order and select the top 5
top_5_genres = genre_ratings_runtime.nlargest(5, 'averagerating')

# Create a bar graph to visualize the top 5 highest-rated genres
plt.figure(figsize=(9, 7))
plt.barh(top_5_genres['genres'], top_5_genres['averagerating'], label='Average Rating')
plt.barh(top_5_genres['genres'], top_5_genres['runtime_minutes'], label='Average Runtime (minutes)')
#plt.bar(genre_runtime['genres'], genre_runtime['runtime_minutes'])
plt.xlabel('Average Rating / Average Runtime (minutes)')
plt.ylabel('Movie Genre')
plt.title('Top 5 Highest-Rated Movie Genres with Average Runtime')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)  
plt.tight_layout()

plt.show()

# %%
#Histogram Average Ratings by Genre
genre_ratings = title_rating_df.groupby('genres')['averagerating'].mean().reset_index()

# Create a histogram of the average ratings for each genre
plt.figure(figsize=(10, 6))
plt.hist(genre_ratings['averagerating'], bins=20, edgecolor='k', alpha=0.7)
plt.xlabel('averagerating')
plt.ylabel('Frequency')
plt.title('Histogram of Average Ratings by Genre')
plt.grid(True)

# Show the histogram
plt.show()

# %% [markdown]
# # Conclusion
# Based on the analysis microsoft company can rely on the following recomendations in order to create a movie studio.
# -  Microsoft should focus in creating Comedy,Documentaries,Fantasy genres which have the highest rating.
# -  Microsoft should work with BV studio to be able to get hand in information and necessary skills to create their own movie
#    studio.
# -  The most suitable lenths of the movies created should be between 60 to 80 runtime minutes.
